# %%
import pandas as pd

df=pd.read_csv("automobile.csv",header=0)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base  length  width  ...  highway-mpg  \
# 0          rwd           front        88.6   168.8   64.1  ...           27
# 1          rwd           front        88.6   168.8   64.1  ...           27
# 2          rwd           front        94.5   171.2   65.5  ...           26
# 3          fwd           front        99.8   176.6   66.2  ...           30
# 4          4wd           front        99.4   176.6   66.4  ...           22
#
#      price horsepower-binned price-binned  diesel gas  std  turbo  \
# 0  13495.0               Low          Low       0   1    1      0
# 1  16500.0               Low          Low       0   1    1      0
# 2  16500.0            Medium          Low       0   1    1      0
# 3  13950.0               Low          Low       0   1    1      0
# 4  17450.0               Low          Low       0   1    1      0
#
#    city-L/100km  highway-L/100km
# 0     11.190476         8.703704
# 1     11.190476         8.703704
# 2     12.368421         9.038462
# 3      9.791667         7.833333
# 4     13.055556        10.681818
#
# [5 rows x 32 columns]

# %%
from sklearn.linear_model import LinearRegression

lm=LinearRegression()
X=df[["highway-mpg"]]
Y=df[["price"]]
lm.fit(X,Y)
Yhat=lm.predict(X)

# %%
ax1=sns.distplot(df["price"],hist=False,color="r",label="actual value")
sns.distplot(Yhat,hist=False,color="b",label="fitted value",ax=ax1)

# %%
lm.intercept_
# Out:
# array([38423.30585816])

# %%
lm.coef_
# Out:
# array([[-821.73337832]])

# %%
import seaborn as sns

sns.regplot(x="highway-mpg",y="price",data=df)

# %%
sm=LinearRegression()
z=df[["horsepower","curb-weight","engine-size","highway-mpg"]]
sm.fit(z,df["price"])
# Out:
# LinearRegression()

# %%
yhat=sm.predict(z)

# %%
sm.intercept_
sm.coef_
# Out:
# array([53.53022809,  4.70805253, 81.51280006, 36.1593925 ])

# %%
sm.intercept_
# Out:
# -15811.863767729232

# %%
sns.residplot(df["highway-mpg"],df["price"])

# %%
sns.residplot(df[["horsepower"]],df["price"])

# %%
ax1=sns.distplot(df["price"],hist=False,color="r",label="actual value")
sns.distplot(yhat,hist=False,color="b",label="fitted value",ax=ax1)

# %%
import csv 

with open("automobile.csv") as f:
# Out:
# <class 'str'>
# symboling,normalized-losses,make,num-of-doors,body-style,drive-wheels,engine-location,wheel-base,length,width,height,curb-weight,engine-type,num-of-cylinders,engine-size,fuel-system,bore,stroke,compression-ratio,horsepower,peak-rpm,city-mpg,highway-mpg,price,horsepower-binned,price-binned,diesel,gas,std,turbo,city-L/100km,highway-L/100km
#
# <class 'str'>
# 3,122,alfa-romero,two,convertible,rwd,front,88.6,168.8,64.1,0.8160535117056856,2548,dohc,four,130,mpfi,3.47,2.68,9.0,111,5000.0,21,27,13495.0,Low,Low,0,1,1,0,11.19047619047619,8.703703703703704
#
# <class 'str'>
# 3,122,alfa-romero,two,convertible,rwd,front,88.6,168.8,64.1,0.8160535117056856,2548,dohc,four,130,mpfi,3.47,2.68,9.0,111,5000.0,21,27,16500.0,Low,Low,0,1,1,0,11.19047619047619,8.703703703703704
#
# <class 'str'>
# 1,122,alfa-romero,two,hatchback,rwd,front,94.5,171.2,65.5,0.8762541806020067,2823,ohcv,six,152,mpfi,2.68,3.47,9.0,154,5000.0,19,26,16500.0,Medium,Low,0,1,1,0,12.368421052631579,9.038461538461538

# %%
print(lines)
# Out:
# <_csv.reader object at 0x126ea5c50>
