# %%
# %matplotlib widget
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns  # data visualization library  
import matplotlib.pyplot as plt
import time

df=pd.read_csv("data.csv")
y=df.diagnosis
df.drop(["id","diagnosis","Unnamed: 32"],axis=1,inplace=True)

# %%
plt.figure()
sns.countplot(y,label="Count");
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df.describe()
# Out:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -3.136331e-15 -6.558316e-15   -7.012551e-16 -8.339355e-16
# std    1.000000e+00  1.000000e+00    1.000000e+00  1.000000e+00
# min   -2.027864e+00 -2.227289e+00   -1.982759e+00 -1.453164e+00
# 25%   -6.887793e-01 -7.253249e-01   -6.913472e-01 -6.666089e-01
# 50%   -2.148925e-01 -1.045442e-01   -2.357726e-01 -2.949274e-01
# 75%    4.689800e-01  5.836621e-01    4.992377e-01  3.631877e-01
# max    3.967796e+00  4.647799e+00    3.972634e+00  5.245913e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean      6.120470e-15     -1.074321e-15   -4.031144e-16         1.006030e-15
# std       1.000000e+00      1.000000e+00    1.000000e+00         1.000000e+00
# ...

# %%
df=(df-df.mean())/df.std()

# %%
plt.figure(figsize=(15,5))



x=pd.concat([y,df.iloc[:,0:10]],axis=1)
sns.set_context("paper", rc={"font.size":5,"axes.titlesize":5,"axes.labelsize":10})
data=pd.melt(x,id_vars="diagnosis",var_name="features",value_name="value")
ax=plt.subplot(1,3,1)
sns.violinplot(x="features",y="value",ax=ax,data=data,hue="diagnosis",split=True,inner="quart")
plt.xticks(rotation=45);
plt.tick_params(axis="both",labelsize=7)
plt.subplots_adjust(bottom=0.25)

x=pd.concat([y,df.iloc[:,10:20]],axis=1)
sns.set_context("paper", rc={"font.size":5,"axes.titlesize":5,"axes.labelsize":10})
data=pd.melt(x,id_vars="diagnosis",var_name="features",value_name="value")
ax=plt.subplot(1,3,2)
sns.violinplot(x="features",ax=ax,y="value",data=data,hue="diagnosis",split=True,inner="quart")
plt.xticks(rotation=45);
plt.tick_params(axis="both",labelsize=7)
plt.subplots_adjust(bottom=0.25)

x=pd.concat([y,df.iloc[:,20:]],axis=1)
sns.set_context("paper", rc={"font.size":5,"axes.titlesize":5,"axes.labelsize":10})
data=pd.melt(x,id_vars="diagnosis",var_name="features",value_name="value")
ax=plt.subplot(1,3,3)
sns.violinplot(ax=ax,x="features",y="value",data=data,hue="diagnosis",split=True,inner="quart")
plt.xticks(rotation=45);
plt.tick_params(axis="both",labelsize=7)
plt.subplots_adjust(bottom=0.25)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(21,7))

x=pd.concat([y,df.iloc[:,0:10]],axis=1)
sns.set_context("paper", rc={"font.size":5,"axes.titlesize":5,"axes.labelsize":10})
data=pd.melt(x,id_vars="diagnosis",var_name="features",value_name="value")
plt.subplot(1,3,1)
sns.swarmplot(x="features",y="value",ax=plt.gca(),data=data,hue="diagnosis")
plt.xticks(rotation=45);
plt.tick_params(axis="both",labelsize=7)
plt.subplots_adjust(bottom=0.25)

x=pd.concat([y,df.iloc[:,10:20]],axis=1)
sns.set_context("paper", rc={"font.size":5,"axes.titlesize":5,"axes.labelsize":10})
data=pd.melt(x,id_vars="diagnosis",var_name="features",value_name="value")
plt.subplot(1,3,2)
sns.swarmplot(x="features",y="value",data=data,ax=plt.gca(),hue="diagnosis")
plt.xticks(rotation=45);
plt.tick_params(axis="both",labelsize=7)
plt.subplots_adjust(bottom=0.25)

x=pd.concat([y,df.iloc[:,20:]],axis=1)
sns.set_context("paper", rc={"font.size":5,"axes.titlesize":5,"axes.labelsize":10})
data=pd.melt(x,id_vars="diagnosis",var_name="features",value_name="value")
plt.subplot(1,3,3)
sns.swarmplot(x="features",y="value",data=data,hue="diagnosis",ax=plt.gca())
plt.xticks(rotation=45);
plt.tick_params(axis="both",labelsize=7)
plt.subplots_adjust(bottom=0.25)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sns.set_context("paper", rc={"font.size":8,"axes.titlesize":8,"axes.labelsize":5})
f,ax=plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,fmt=".1f",ax=ax);
plt.subplots_adjust(bottom=0.25,left=0.2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sns.scatterplot()
