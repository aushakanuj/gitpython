# %%
# %matplotlib widget 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.colors
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("test.csv")

# %%
df.shape
# Out:
# (4398, 202)

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime  has_collection  \
# count  4398.000000  4.398000e+03  4398.000000  4394.000000     4398.000000
# mean   5199.500000  2.264929e+07     8.550230   107.622212        0.199409
# std    1269.737571  3.689991e+07    12.209014    21.058290        0.399601
# min    3001.000000  0.000000e+00     0.000001     0.000000        0.000000
# 25%    4100.250000  0.000000e+00     3.895186    94.000000        0.000000
# 50%    5199.500000  7.450000e+06     7.482241   104.000000        0.000000
# 75%    6298.750000  2.800000e+07    10.938524   118.000000        0.000000
# max    7398.000000  2.600000e+08   547.488298   320.000000        1.000000
#
#         num_genres  genre_Drama  genre_Comedy  genre_Thriller  genre_Action  \
# count  4398.000000  4398.000000   4398.000000     4398.000000   4398.000000
# mean      2.489995     0.487722      0.358572        0.245566      0.226012
# ...
