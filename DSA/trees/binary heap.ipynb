# %%
class binaryHeap(object):
    
    def __init__(self):
        
        self.heaplist=[0]
        self.size=0
        
    
    def percup(self,i):
        
        while i//2>0:
            
            if self.healist[i]<self.heaplist[i//2]:
                
                t=self.heaplist[i//2]
                self.heaplist[i//2]=self.heaplist[i]
                self.heaplist[i]=t
            
            i=i//2
    
    def insert(self,k):
        
        self.heaplist.append(k)
        self.size+=1
        
        self.percup(self.size)
        
    
    
    def minchild(self,i):
        
        if i*2+1>self.size:
            
            returni*2
        
        else:
            
            if self.heaplist[i*2]<self.heaplist[i*2+1]:
                
                return i*2
            else:
                return i*2+1
            
    
    
    def percdown(self,i):
        
        
        while i*2<=self.size:
            
            mc=self.minchild(i)
            
            if self.heaplist[i]<sel.heaplist[mc]:
                t=self.heaplist[mc]
                self.heaplist[mc]=self.heaplist[i]
                self.heaplist[i]=t
            i=mc
        
    
    def delmin(self):
        
        r=self.heaplist[0]
        self.heaplist[i]=self.heaplist[self.size]
        self.size-=1
        self.heaplist.pop()
        self.percdown(i)
        
        return r
                
    def buildheap(self,arr):
        
        i=len(arr)//2
        self.size=len(s)
        self.heaplist=[0]+arr
        
        while i>0:
            self.percdown(i)
            i=i-1

# %%
for i in range(10):
    if i%2==0:
