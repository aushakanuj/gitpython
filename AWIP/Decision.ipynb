# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
import sklearn.model_selection as model_selection
from utilities2 import visualize_classifier
# %matplotlib widget

# %%
# Load input data
input_file = 'data_decision_trees.txt'
data = np.loadtxt(input_file, delimiter=',')
X, y = data[:, :-1], data[:, -1]

# %%
# Separate input data into two classes based on labels
class_0 = np.array(X[y==0])
class_1 = np.array(X[y==1])

# %%
class_1
# Out:
# array([[ 2.58,  9.88],
#        [ 8.3 ,  5.36],
#        [ 3.41,  1.46],
#        [ 2.18,  8.08],
#        [ 7.41,  5.87],
#        [ 2.6 ,  1.7 ],
#        [ 1.88,  7.33],
#        [ 7.93,  6.52],
#        [ 3.1 ,  3.05],
#        [ 2.02,  8.78],
#        [ 8.9 ,  4.67],
#        [ 2.53,  2.63],
#        [ 3.54,  7.7 ],
#        [ 6.44,  4.94],
#        [ 3.34,  2.62],
#        [ 2.35,  7.94],
#        [ 7.86,  4.65],
#        [ 4.47,  1.69],
#        [ 2.88,  7.87],
#        [ 7.21,  5.37],
#        [ 2.46,  2.61],
#        [ 2.11,  8.14],
#        [ 8.68,  5.61],
#        [ 3.19,  2.19],
#        [ 1.59,  8.38],
#        [ 6.98,  4.72],
#        [ 2.9 ,  3.02],
#        [ 1.08,  7.69],
#        [ 8.13,  5.58],
#        [ 3.13,  1.68],
#        [ 2.85,  6.91],
#        [ 8.68,  5.95],
#        [ 3.69,  1.27],
#        [ 2.46,  8.31],
#        [ 7.81,  4.54],
#        [ 2.8 ,  1.32],
#        [ 2.18,  8.42],
#        [ 8.22,  5.77],
#        [ 4.04,  1.1 ],
#        [ 2.53,  7.92],
#        [ 7.31,  5.45],
#        [ 3.35,  2.18],
#        [ 1.94,  8.62],
#        [ 7.15,  6.57],
#        [ 2.95,  1.22],
#        [ 3.38,  7.45],
#        [ 8.86,  4.62],
#        [ 1.54,  1.67],
#        [ 2.12,  8.41],
#        [ 7.14,  4.97],
#        [ 4.6 ,  1.57],
#        [ 1.87,  8.12],
#        [ 8.17,  4.38],
#        [ 2.86,  1.48],
#        [ 0.75,  8.36],
#        [ 8.45,  5.37],
#        [ 4.27,  1.52],
#        [ 3.6 ,  8.2 ],
#        [ 8.3 ,  5.82],
#        [ 2.4 ,  2.25],
#        [ 1.23,  7.82],
#        [ 7.08,  5.55],
#        [ 3.5 ,  1.59],
#        [ 2.89,  8.32],
#        [ 8.81,  6.08],
#        [ 2.48,  2.35],
#        [ 3.58,  7.91],
#        [ 9.32,  4.43],
#        [ 4.27,  3.07],
#        [ 2.96,  7.92],
#        [ 8.17,  5.8 ],
#        [ 2.76,  1.11],
#        [ 2.98,  7.88],
#        [ 8.27,  4.42],
#        [ 2.93,  1.1 ],
#        [ 1.52,  8.73],
#        [ 7.78,  5.37],
#        [ 3.77,  1.01],
#        [ 1.51,  7.27],
#        [ 8.27,  4.91],
#        [ 1.97,  0.35],
#        [ 3.46,  9.07],
#        [10.18,  5.05],
#        [ 3.15,  2.59],
#        [ 3.21,  7.98],
#        [ 7.64,  4.45],
#        [ 2.94,  2.61],
#        [ 1.57,  8.23],
#        [ 8.27,  5.66],
#        [ 2.11,  2.06],
#        [ 3.16,  7.96],
#        [ 9.3 ,  6.11],
#        [ 1.79,  3.3 ],
#        [ 1.79,  7.8 ],
#        [ 7.58,  5.98],
#        [ 2.5 ,  3.  ],
#        [ 1.75,  8.06],
#        [ 8.1 ,  5.6 ],
#        [ 3.18,  1.51],
#        [ 2.34,  8.02],
#        [ 8.5 ,  4.71],
#        [ 3.33,  2.34],
#        [ 2.43,  7.84],
#        [ 8.06,  5.49],
#        [ 2.89,  0.89],
#        [ 1.56,  8.29],
#        [ 6.87,  5.5 ],
#        [ 3.67,  1.78],
#        [ 1.86,  8.58],
#        [ 8.29,  6.11],
#        [ 1.71,  1.34],
#        [ 2.99,  8.51],
#        [ 8.89,  4.74],
#        [ 1.97,  2.54],
#        [ 2.15,  8.08],
#        [ 9.23,  5.55],
#        [ 2.5 ,  2.24],
#        [ 3.77,  6.38],
#        [ 7.69,  4.22],
#        [ 3.47,  1.37],
#        [ 2.11,  8.13],
#        [ 7.92,  6.32],
#        [ 3.39,  1.44],
#        [ 2.79,  9.68],
#        [ 8.96,  5.35],
#        [ 3.43,  2.07],
#        [ 2.5 ,  7.6 ],
#        [ 6.49,  4.83],
#        [ 4.09,  2.58],
#        [ 1.5 ,  9.46],
#        [ 8.33,  5.42],
#        [ 3.07,  2.51],
#        [ 2.76,  8.45],
#        [ 8.38,  6.21],
#        [ 3.15,  2.1 ],
#        [ 2.42,  8.57],
#        [ 7.59,  5.78],
#        [ 3.78,  1.37],
#        [ 1.98,  8.97],
#        [ 7.07,  6.61],
#        [ 3.71,  1.88],
#        [ 2.52,  8.14],
#        [ 8.54,  5.15],
#        [ 2.7 ,  0.43],
#        [ 2.52,  7.32],
#        [ 7.9 ,  5.05],
#        [ 2.98,  1.86],
#        [ 1.6 ,  8.85],
#        [ 9.08,  5.46],
#        [ 3.85,  3.76],
#        [ 3.49,  7.84],
#        [ 8.95,  5.95],
#        [ 2.99,  1.77],
#        [ 3.71,  8.84],
#        [ 8.25,  4.83],
#        [ 2.91,  2.53],
#        [ 3.02,  7.22],
#        [ 7.24,  4.67],
#        [ 3.09,  2.43],
#        [ 2.02,  7.92],
#        [ 8.05,  6.65],
#        [ 2.55,  2.65],
#        [ 1.89,  9.15],
#        [ 7.14,  5.64],
#        [ 3.42,  1.41],
#        [ 2.24,  7.66],
#        [ 7.78,  5.83],
#        [ 2.65,  1.09],
#        [ 2.71,  8.98],
#        [ 7.02,  6.16],
#        [ 3.48,  1.63],
#        [ 1.78,  8.26],
#        [ 8.04,  5.83],
#        [ 3.24,  1.55],
#        [ 2.49,  8.73],
#        [ 7.55,  5.34],
#        [ 2.18,  2.04],
#        [ 5.58,  7.17],
#        [ 8.62,  6.02],
#        [ 3.05,  2.11]])

# %%
# Visualize input data
plt.figure()
plt.scatter(class_0[:, 0], class_0[:, 1], s=75, facecolors='black', 
        edgecolors='black', linewidth=1, marker='x')
plt.scatter(class_1[:, 0], class_1[:, 1], s=75, facecolors='white', 
        edgecolors='black', linewidth=1, marker='o')
plt.title('Input data')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'Input data')

# %%
# Split data into training and testing datasets 
X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, y, test_size=0.25, random_state=5)

# %%
# Decision Trees classifier 
params = {'random_state': 0, 'max_depth': 4}
classifier = DecisionTreeClassifier(**params)
classifier.fit(X_train, y_train)
visualize_classifier(classifier, X_train, y_train, 'Training dataset')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /Users/aushakanuz/Documents/gitpython/AWIP/utilities2.py:29: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(x_vals, y_vals, output, cmap=plt.cm.gray)

# %%
y_test_pred = classifier.predict(X_test)
visualize_classifier(classifier, X_test, y_test, 'Test dataset')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /Users/aushakanuz/Documents/gitpython/AWIP/utilities2.py:29: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(x_vals, y_vals, output, cmap=plt.cm.gray)

# %%
# Evaluate classifier performance
class_names = ['Class-0', 'Class-1']
print("\n" + "#"*40)
print("\nClassifier performance on training dataset\n")
print(classification_report(y_train, classifier.predict(X_train), target_names=class_names))
print("#"*40 + "\n")
# Out:
# ########################################
#
# Classifier performance on training dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.99      1.00      1.00       137
#      Class-1       1.00      0.99      1.00       133
#
#     accuracy                           1.00       270
#    macro avg       1.00      1.00      1.00       270
# weighted avg       1.00      1.00      1.00       270
#
# ########################################

# %%
print("#"*40)
print("\nClassifier performance on test dataset\n")
print(classification_report(y_test, y_test_pred, target_names=class_names))
print("#"*40 + "\n")
# Out:
# ########################################
#
# Classifier performance on test dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.93      1.00      0.97        43
#      Class-1       1.00      0.94      0.97        47
#
#     accuracy                           0.97        90
#    macro avg       0.97      0.97      0.97        90
# weighted avg       0.97      0.97      0.97        90
#
# ########################################

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from utilities import visualize_classifier

input_file = 'data_random_forests.txt'
data = np.loadtxt(input_file, delimiter=',')
X, y = data[:, :-1], data[:, -1]

# Separate input data into three classes based on labels
class_0 = np.array(X[y==0])
class_1 = np.array(X[y==1])
class_2 = np.array(X[y==2])


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)

# %%
from sklearn.model_selection import GridSearchCV 

# defining parameter range 
param_grid = {'n_estimators': [10, 100, 200, 300, 400, 500, 750, 1000], 
			'max_depth': [1, 2, 3, 4, 5, 6]} 


from sklearn.ensemble import RandomForestClassifier
grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3)

grid.fit(X_train, y_train)

# print best parameter after tuning 
print(grid.best_params_) 

# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_)

grid_predictions = grid.predict(X_test) 

# print classification report 
print(confusion_matrix(y_test,grid_predictions))
print(classification_report(y_test, grid_predictions))
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] max_depth=1, n_estimators=10 ....................................
# [CV] ........ max_depth=1, n_estimators=10, score=0.815, total=   0.1s
# [CV] max_depth=1, n_estimators=10 ....................................
# [CV] ........ max_depth=1, n_estimators=10, score=0.830, total=   0.1s
# [CV] max_depth=1, n_estimators=10 ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] ........ max_depth=1, n_estimators=10, score=0.748, total=   0.1s
# [CV] max_depth=1, n_estimators=10 ....................................
# [CV] ........ max_depth=1, n_estimators=10, score=0.741, total=   0.0s
# [CV] max_depth=1, n_estimators=10 ....................................
# [CV] ........ max_depth=1, n_estimators=10, score=0.822, total=   0.0s
# [CV] max_depth=1, n_estimators=100 ...................................
# [CV] ....... max_depth=1, n_estimators=100, score=0.830, total=   0.3s
# [CV] max_depth=1, n_estimators=100 ...................................
# [CV] ....... max_depth=1, n_estimators=100, score=0.837, total=   0.2s
# [CV] max_depth=1, n_estimators=100 ...................................
# [CV] ....... max_depth=1, n_estimators=100, score=0.793, total=   0.2s
# [CV] max_depth=1, n_estimators=100 ...................................
# [CV] ....... max_depth=1, n_estimators=100, score=0.763, total=   0.2s
# [CV] max_depth=1, n_estimators=100 ...................................
# [CV] ....... max_depth=1, n_estimators=100, score=0.837, total=   0.3s
# [CV] max_depth=1, n_estimators=200 ...................................
# [CV] ....... max_depth=1, n_estimators=200, score=0.837, total=   0.6s
# [CV] max_depth=1, n_estimators=200 ...................................
# [CV] ....... max_depth=1, n_estimators=200, score=0.837, total=   0.4s
# [CV] max_depth=1, n_estimators=200 ...................................
# [CV] ....... max_depth=1, n_estimators=200, score=0.778, total=   0.4s
# [CV] max_depth=1, n_estimators=200 ...................................
# [CV] ....... max_depth=1, n_estimators=200, score=0.778, total=   0.5s
# [CV] max_depth=1, n_estimators=200 ...................................
# [CV] ....... max_depth=1, n_estimators=200, score=0.830, total=   0.4s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV] ....... max_depth=1, n_estimators=300, score=0.837, total=   0.7s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV] ....... max_depth=1, n_estimators=300, score=0.859, total=   0.7s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV] ....... max_depth=1, n_estimators=300, score=0.778, total=   0.7s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV] ....... max_depth=1, n_estimators=300, score=0.770, total=   1.1s
# [CV] max_depth=1, n_estimators=300 ...................................
# [CV] ....... max_depth=1, n_estimators=300, score=0.822, total=   1.5s
# [CV] max_depth=1, n_estimators=400 ...................................
# [CV] ....... max_depth=1, n_estimators=400, score=0.837, total=   1.9s
# [CV] max_depth=1, n_estimators=400 ...................................
# [CV] ....... max_depth=1, n_estimators=400, score=0.822, total=   1.0s
# [CV] max_depth=1, n_estimators=400 ...................................
# [CV] ....... max_depth=1, n_estimators=400, score=0.778, total=   1.3s
# [CV] max_depth=1, n_estimators=400 ...................................
# [CV] ....... max_depth=1, n_estimators=400, score=0.770, total=   1.4s
# [CV] max_depth=1, n_estimators=400 ...................................
# [CV] ....... max_depth=1, n_estimators=400, score=0.822, total=   1.2s
# [CV] max_depth=1, n_estimators=500 ...................................
# [CV] ....... max_depth=1, n_estimators=500, score=0.822, total=   1.6s
# [CV] max_depth=1, n_estimators=500 ...................................
# [CV] ....... max_depth=1, n_estimators=500, score=0.830, total=   1.7s
# [CV] max_depth=1, n_estimators=500 ...................................
# [CV] ....... max_depth=1, n_estimators=500, score=0.770, total=   1.1s
# [CV] max_depth=1, n_estimators=500 ...................................
# [CV] ....... max_depth=1, n_estimators=500, score=0.778, total=   1.1s
# [CV] max_depth=1, n_estimators=500 ...................................
# [CV] ....... max_depth=1, n_estimators=500, score=0.830, total=   1.1s
# [CV] max_depth=1, n_estimators=750 ...................................
# [CV] ....... max_depth=1, n_estimators=750, score=0.830, total=   2.1s
# [CV] max_depth=1, n_estimators=750 ...................................
# [CV] ....... max_depth=1, n_estimators=750, score=0.852, total=   2.8s
# [CV] max_depth=1, n_estimators=750 ...................................
# [CV] ....... max_depth=1, n_estimators=750, score=0.770, total=   1.6s
# [CV] max_depth=1, n_estimators=750 ...................................
# [CV] ....... max_depth=1, n_estimators=750, score=0.800, total=   1.6s
# [CV] max_depth=1, n_estimators=750 ...................................
# [CV] ....... max_depth=1, n_estimators=750, score=0.830, total=   1.6s
# [CV] max_depth=1, n_estimators=1000 ..................................
# [CV] ...... max_depth=1, n_estimators=1000, score=0.830, total=   2.6s
# [CV] max_depth=1, n_estimators=1000 ..................................
# [CV] ...... max_depth=1, n_estimators=1000, score=0.852, total=   3.3s
# [CV] max_depth=1, n_estimators=1000 ..................................
# [CV] ...... max_depth=1, n_estimators=1000, score=0.785, total=   2.8s
# [CV] max_depth=1, n_estimators=1000 ..................................
# [CV] ...... max_depth=1, n_estimators=1000, score=0.778, total=   2.9s
# [CV] max_depth=1, n_estimators=1000 ..................................
# [CV] ...... max_depth=1, n_estimators=1000, score=0.822, total=   2.1s
# [CV] max_depth=2, n_estimators=10 ....................................
# [CV] ........ max_depth=2, n_estimators=10, score=0.844, total=   0.0s
# [CV] max_depth=2, n_estimators=10 ....................................
# [CV] ........ max_depth=2, n_estimators=10, score=0.859, total=   0.0s
# [CV] max_depth=2, n_estimators=10 ....................................
# [CV] ........ max_depth=2, n_estimators=10, score=0.785, total=   0.0s
# [CV] max_depth=2, n_estimators=10 ....................................
# [CV] ........ max_depth=2, n_estimators=10, score=0.800, total=   0.0s
# [CV] max_depth=2, n_estimators=10 ....................................
# [CV] ........ max_depth=2, n_estimators=10, score=0.822, total=   0.0s
# [CV] max_depth=2, n_estimators=100 ...................................
# [CV] ....... max_depth=2, n_estimators=100, score=0.852, total=   0.2s
# [CV] max_depth=2, n_estimators=100 ...................................
# [CV] ....... max_depth=2, n_estimators=100, score=0.830, total=   0.2s
# [CV] max_depth=2, n_estimators=100 ...................................
# [CV] ....... max_depth=2, n_estimators=100, score=0.800, total=   0.2s
# [CV] max_depth=2, n_estimators=100 ...................................
# [CV] ....... max_depth=2, n_estimators=100, score=0.800, total=   0.3s
# [CV] max_depth=2, n_estimators=100 ...................................
# [CV] ....... max_depth=2, n_estimators=100, score=0.844, total=   0.3s
# [CV] max_depth=2, n_estimators=200 ...................................
# [CV] ....... max_depth=2, n_estimators=200, score=0.867, total=   0.5s
# [CV] max_depth=2, n_estimators=200 ...................................
# [CV] ....... max_depth=2, n_estimators=200, score=0.830, total=   0.5s
# [CV] max_depth=2, n_estimators=200 ...................................
# [CV] ....... max_depth=2, n_estimators=200, score=0.807, total=   0.4s
# [CV] max_depth=2, n_estimators=200 ...................................
# [CV] ....... max_depth=2, n_estimators=200, score=0.815, total=   0.4s
# [CV] max_depth=2, n_estimators=200 ...................................
# [CV] ....... max_depth=2, n_estimators=200, score=0.852, total=   0.4s
# [CV] max_depth=2, n_estimators=300 ...................................
# [CV] ....... max_depth=2, n_estimators=300, score=0.852, total=   0.6s
# [CV] max_depth=2, n_estimators=300 ...................................
# [CV] ....... max_depth=2, n_estimators=300, score=0.837, total=   0.6s
# [CV] max_depth=2, n_estimators=300 ...................................
# [CV] ....... max_depth=2, n_estimators=300, score=0.807, total=   0.8s
# [CV] max_depth=2, n_estimators=300 ...................................
# [CV] ....... max_depth=2, n_estimators=300, score=0.800, total=   0.7s
# [CV] max_depth=2, n_estimators=300 ...................................
# [CV] ....... max_depth=2, n_estimators=300, score=0.830, total=   0.7s
# [CV] max_depth=2, n_estimators=400 ...................................
# [CV] ....... max_depth=2, n_estimators=400, score=0.852, total=   0.8s
# [CV] max_depth=2, n_estimators=400 ...................................
# [CV] ....... max_depth=2, n_estimators=400, score=0.852, total=   1.0s
# [CV] max_depth=2, n_estimators=400 ...................................
# [CV] ....... max_depth=2, n_estimators=400, score=0.807, total=   1.1s
# [CV] max_depth=2, n_estimators=400 ...................................
# [CV] ....... max_depth=2, n_estimators=400, score=0.815, total=   0.9s
# [CV] max_depth=2, n_estimators=400 ...................................
# [CV] ....... max_depth=2, n_estimators=400, score=0.852, total=   0.8s
# [CV] max_depth=2, n_estimators=500 ...................................
# [CV] ....... max_depth=2, n_estimators=500, score=0.852, total=   1.0s
# [CV] max_depth=2, n_estimators=500 ...................................
# [CV] ....... max_depth=2, n_estimators=500, score=0.844, total=   1.0s
# [CV] max_depth=2, n_estimators=500 ...................................
# [CV] ....... max_depth=2, n_estimators=500, score=0.807, total=   1.0s
# [CV] max_depth=2, n_estimators=500 ...................................
# [CV] ....... max_depth=2, n_estimators=500, score=0.807, total=   1.0s
# [CV] max_depth=2, n_estimators=500 ...................................
# [CV] ....... max_depth=2, n_estimators=500, score=0.837, total=   1.2s
# [CV] max_depth=2, n_estimators=750 ...................................
# [CV] ....... max_depth=2, n_estimators=750, score=0.852, total=   1.6s
# [CV] max_depth=2, n_estimators=750 ...................................
# [CV] ....... max_depth=2, n_estimators=750, score=0.837, total=   1.5s
# [CV] max_depth=2, n_estimators=750 ...................................
# [CV] ....... max_depth=2, n_estimators=750, score=0.807, total=   1.6s
# [CV] max_depth=2, n_estimators=750 ...................................
# [CV] ....... max_depth=2, n_estimators=750, score=0.822, total=   1.7s
# [CV] max_depth=2, n_estimators=750 ...................................
# [CV] ....... max_depth=2, n_estimators=750, score=0.852, total=   1.5s
# [CV] max_depth=2, n_estimators=1000 ..................................
# [CV] ...... max_depth=2, n_estimators=1000, score=0.852, total=   2.6s
# [CV] max_depth=2, n_estimators=1000 ..................................
# [CV] ...... max_depth=2, n_estimators=1000, score=0.837, total=   2.1s
# [CV] max_depth=2, n_estimators=1000 ..................................
# [CV] ...... max_depth=2, n_estimators=1000, score=0.815, total=   2.0s
# [CV] max_depth=2, n_estimators=1000 ..................................
# [CV] ...... max_depth=2, n_estimators=1000, score=0.822, total=   2.7s
# [CV] max_depth=2, n_estimators=1000 ..................................
# [CV] ...... max_depth=2, n_estimators=1000, score=0.837, total=   2.2s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ........ max_depth=3, n_estimators=10, score=0.830, total=   0.0s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ........ max_depth=3, n_estimators=10, score=0.852, total=   0.0s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ........ max_depth=3, n_estimators=10, score=0.807, total=   0.0s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ........ max_depth=3, n_estimators=10, score=0.793, total=   0.0s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ........ max_depth=3, n_estimators=10, score=0.844, total=   0.0s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] ....... max_depth=3, n_estimators=100, score=0.852, total=   0.2s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] ....... max_depth=3, n_estimators=100, score=0.844, total=   0.4s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] ....... max_depth=3, n_estimators=100, score=0.822, total=   0.3s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] ....... max_depth=3, n_estimators=100, score=0.815, total=   0.4s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] ....... max_depth=3, n_estimators=100, score=0.844, total=   0.3s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] ....... max_depth=3, n_estimators=200, score=0.859, total=   0.6s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] ....... max_depth=3, n_estimators=200, score=0.852, total=   0.6s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] ....... max_depth=3, n_estimators=200, score=0.800, total=   0.4s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] ....... max_depth=3, n_estimators=200, score=0.807, total=   0.6s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] ....... max_depth=3, n_estimators=200, score=0.844, total=   0.5s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV] ....... max_depth=3, n_estimators=300, score=0.852, total=   0.7s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV] ....... max_depth=3, n_estimators=300, score=0.852, total=   1.1s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV] ....... max_depth=3, n_estimators=300, score=0.815, total=   1.8s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV] ....... max_depth=3, n_estimators=300, score=0.807, total=   0.8s
# [CV] max_depth=3, n_estimators=300 ...................................
# [CV] ....... max_depth=3, n_estimators=300, score=0.852, total=   0.7s
# [CV] max_depth=3, n_estimators=400 ...................................
# [CV] ....... max_depth=3, n_estimators=400, score=0.852, total=   1.1s
# [CV] max_depth=3, n_estimators=400 ...................................
# [CV] ....... max_depth=3, n_estimators=400, score=0.844, total=   1.3s
# [CV] max_depth=3, n_estimators=400 ...................................
# [CV] ....... max_depth=3, n_estimators=400, score=0.800, total=   1.0s
# [CV] max_depth=3, n_estimators=400 ...................................
# [CV] ....... max_depth=3, n_estimators=400, score=0.815, total=   1.0s
# [CV] max_depth=3, n_estimators=400 ...................................
# [CV] ....... max_depth=3, n_estimators=400, score=0.844, total=   1.0s
# [CV] max_depth=3, n_estimators=500 ...................................
# [CV] ....... max_depth=3, n_estimators=500, score=0.859, total=   1.2s
# [CV] max_depth=3, n_estimators=500 ...................................
# [CV] ....... max_depth=3, n_estimators=500, score=0.852, total=   1.3s
# [CV] max_depth=3, n_estimators=500 ...................................
# [CV] ....... max_depth=3, n_estimators=500, score=0.815, total=   1.4s
# [CV] max_depth=3, n_estimators=500 ...................................
# [CV] ....... max_depth=3, n_estimators=500, score=0.815, total=   1.2s
# [CV] max_depth=3, n_estimators=500 ...................................
# [CV] ....... max_depth=3, n_estimators=500, score=0.852, total=   1.3s
# [CV] max_depth=3, n_estimators=750 ...................................
# [CV] ....... max_depth=3, n_estimators=750, score=0.852, total=   2.0s
# [CV] max_depth=3, n_estimators=750 ...................................
# [CV] ....... max_depth=3, n_estimators=750, score=0.852, total=   1.6s
# [CV] max_depth=3, n_estimators=750 ...................................
# [CV] ....... max_depth=3, n_estimators=750, score=0.807, total=   1.7s
# [CV] max_depth=3, n_estimators=750 ...................................
# [CV] ....... max_depth=3, n_estimators=750, score=0.815, total=   1.6s
# [CV] max_depth=3, n_estimators=750 ...................................
# [CV] ....... max_depth=3, n_estimators=750, score=0.859, total=   1.6s
# [CV] max_depth=3, n_estimators=1000 ..................................
# [CV] ...... max_depth=3, n_estimators=1000, score=0.852, total=   2.1s
# [CV] max_depth=3, n_estimators=1000 ..................................
# [CV] ...... max_depth=3, n_estimators=1000, score=0.852, total=   2.1s
# [CV] max_depth=3, n_estimators=1000 ..................................
# [CV] ...... max_depth=3, n_estimators=1000, score=0.807, total=   2.4s
# [CV] max_depth=3, n_estimators=1000 ..................................
# [CV] ...... max_depth=3, n_estimators=1000, score=0.815, total=   2.3s
# [CV] max_depth=3, n_estimators=1000 ..................................
# [CV] ...... max_depth=3, n_estimators=1000, score=0.852, total=   2.2s
# [CV] max_depth=4, n_estimators=10 ....................................
# [CV] ........ max_depth=4, n_estimators=10, score=0.844, total=   0.0s
# [CV] max_depth=4, n_estimators=10 ....................................
# [CV] ........ max_depth=4, n_estimators=10, score=0.844, total=   0.0s
# [CV] max_depth=4, n_estimators=10 ....................................
# [CV] ........ max_depth=4, n_estimators=10, score=0.807, total=   0.0s
# [CV] max_depth=4, n_estimators=10 ....................................
# [CV] ........ max_depth=4, n_estimators=10, score=0.800, total=   0.0s
# [CV] max_depth=4, n_estimators=10 ....................................
# [CV] ........ max_depth=4, n_estimators=10, score=0.867, total=   0.0s
# [CV] max_depth=4, n_estimators=100 ...................................
# [CV] ....... max_depth=4, n_estimators=100, score=0.844, total=   0.2s
# [CV] max_depth=4, n_estimators=100 ...................................
# [CV] ....... max_depth=4, n_estimators=100, score=0.852, total=   0.2s
# [CV] max_depth=4, n_estimators=100 ...................................
# [CV] ....... max_depth=4, n_estimators=100, score=0.822, total=   0.2s
# [CV] max_depth=4, n_estimators=100 ...................................
# [CV] ....... max_depth=4, n_estimators=100, score=0.800, total=   0.2s
# [CV] max_depth=4, n_estimators=100 ...................................
# [CV] ....... max_depth=4, n_estimators=100, score=0.852, total=   0.2s
# [CV] max_depth=4, n_estimators=200 ...................................
# [CV] ....... max_depth=4, n_estimators=200, score=0.852, total=   0.5s
# [CV] max_depth=4, n_estimators=200 ...................................
# [CV] ....... max_depth=4, n_estimators=200, score=0.852, total=   0.4s
# [CV] max_depth=4, n_estimators=200 ...................................
# [CV] ....... max_depth=4, n_estimators=200, score=0.822, total=   0.4s
# [CV] max_depth=4, n_estimators=200 ...................................
# [CV] ....... max_depth=4, n_estimators=200, score=0.800, total=   0.4s
# [CV] max_depth=4, n_estimators=200 ...................................
# [CV] ....... max_depth=4, n_estimators=200, score=0.844, total=   0.5s
# [CV] max_depth=4, n_estimators=300 ...................................
# [CV] ....... max_depth=4, n_estimators=300, score=0.844, total=   0.7s
# [CV] max_depth=4, n_estimators=300 ...................................
# [CV] ....... max_depth=4, n_estimators=300, score=0.852, total=   0.7s
# [CV] max_depth=4, n_estimators=300 ...................................
# [CV] ....... max_depth=4, n_estimators=300, score=0.807, total=   0.7s
# [CV] max_depth=4, n_estimators=300 ...................................
# [CV] ....... max_depth=4, n_estimators=300, score=0.800, total=   0.7s
# [CV] max_depth=4, n_estimators=300 ...................................
# [CV] ....... max_depth=4, n_estimators=300, score=0.852, total=   0.7s
# [CV] max_depth=4, n_estimators=400 ...................................
# [CV] ....... max_depth=4, n_estimators=400, score=0.852, total=   0.9s
# [CV] max_depth=4, n_estimators=400 ...................................
# [CV] ....... max_depth=4, n_estimators=400, score=0.844, total=   0.9s
# [CV] max_depth=4, n_estimators=400 ...................................
# [CV] ....... max_depth=4, n_estimators=400, score=0.815, total=   0.9s
# [CV] max_depth=4, n_estimators=400 ...................................
# [CV] ....... max_depth=4, n_estimators=400, score=0.800, total=   0.8s
# [CV] max_depth=4, n_estimators=400 ...................................
# [CV] ....... max_depth=4, n_estimators=400, score=0.852, total=   0.9s
# [CV] max_depth=4, n_estimators=500 ...................................
# [CV] ....... max_depth=4, n_estimators=500, score=0.844, total=   1.0s
# [CV] max_depth=4, n_estimators=500 ...................................
# [CV] ....... max_depth=4, n_estimators=500, score=0.852, total=   1.0s
# [CV] max_depth=4, n_estimators=500 ...................................
# [CV] ....... max_depth=4, n_estimators=500, score=0.822, total=   1.1s
# [CV] max_depth=4, n_estimators=500 ...................................
# [CV] ....... max_depth=4, n_estimators=500, score=0.800, total=   1.1s
# [CV] max_depth=4, n_estimators=500 ...................................
# [CV] ....... max_depth=4, n_estimators=500, score=0.852, total=   1.0s
# [CV] max_depth=4, n_estimators=750 ...................................
# [CV] ....... max_depth=4, n_estimators=750, score=0.852, total=   1.9s
# [CV] max_depth=4, n_estimators=750 ...................................
# [CV] ....... max_depth=4, n_estimators=750, score=0.852, total=   1.6s
# [CV] max_depth=4, n_estimators=750 ...................................
# [CV] ....... max_depth=4, n_estimators=750, score=0.815, total=   1.6s
# [CV] max_depth=4, n_estimators=750 ...................................
# [CV] ....... max_depth=4, n_estimators=750, score=0.800, total=   1.5s
# [CV] max_depth=4, n_estimators=750 ...................................
# [CV] ....... max_depth=4, n_estimators=750, score=0.844, total=   1.7s
# [CV] max_depth=4, n_estimators=1000 ..................................
# [CV] ...... max_depth=4, n_estimators=1000, score=0.844, total=   2.2s
# [CV] max_depth=4, n_estimators=1000 ..................................
# [CV] ...... max_depth=4, n_estimators=1000, score=0.852, total=   2.2s
# [CV] max_depth=4, n_estimators=1000 ..................................
# [CV] ...... max_depth=4, n_estimators=1000, score=0.815, total=   2.4s
# [CV] max_depth=4, n_estimators=1000 ..................................
# [CV] ...... max_depth=4, n_estimators=1000, score=0.800, total=   2.1s
# [CV] max_depth=4, n_estimators=1000 ..................................
# [CV] ...... max_depth=4, n_estimators=1000, score=0.852, total=   2.1s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=0.837, total=   0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=0.859, total=   0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=0.793, total=   0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=0.800, total=   0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=0.837, total=   0.0s
# [CV] max_depth=5, n_estimators=100 ...................................
# [CV] ....... max_depth=5, n_estimators=100, score=0.844, total=   0.2s
# [CV] max_depth=5, n_estimators=100 ...................................
# [CV] ....... max_depth=5, n_estimators=100, score=0.859, total=   0.2s
# [CV] max_depth=5, n_estimators=100 ...................................
# [CV] ....... max_depth=5, n_estimators=100, score=0.822, total=   0.2s
# [CV] max_depth=5, n_estimators=100 ...................................
# [CV] ....... max_depth=5, n_estimators=100, score=0.800, total=   0.2s
# [CV] max_depth=5, n_estimators=100 ...................................
# [CV] ....... max_depth=5, n_estimators=100, score=0.859, total=   0.2s
# [CV] max_depth=5, n_estimators=200 ...................................
# [CV] ....... max_depth=5, n_estimators=200, score=0.844, total=   0.5s
# [CV] max_depth=5, n_estimators=200 ...................................
# [CV] ....... max_depth=5, n_estimators=200, score=0.852, total=   0.4s
# [CV] max_depth=5, n_estimators=200 ...................................
# [CV] ....... max_depth=5, n_estimators=200, score=0.815, total=   0.4s
# [CV] max_depth=5, n_estimators=200 ...................................
# [CV] ....... max_depth=5, n_estimators=200, score=0.800, total=   0.4s
# [CV] max_depth=5, n_estimators=200 ...................................
# [CV] ....... max_depth=5, n_estimators=200, score=0.852, total=   0.4s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV] ....... max_depth=5, n_estimators=300, score=0.837, total=   0.7s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV] ....... max_depth=5, n_estimators=300, score=0.867, total=   0.7s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV] ....... max_depth=5, n_estimators=300, score=0.815, total=   0.6s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV] ....... max_depth=5, n_estimators=300, score=0.800, total=   0.6s
# [CV] max_depth=5, n_estimators=300 ...................................
# [CV] ....... max_depth=5, n_estimators=300, score=0.852, total=   0.7s
# [CV] max_depth=5, n_estimators=400 ...................................
# [CV] ....... max_depth=5, n_estimators=400, score=0.844, total=   0.8s
# [CV] max_depth=5, n_estimators=400 ...................................
# [CV] ....... max_depth=5, n_estimators=400, score=0.852, total=   0.8s
# [CV] max_depth=5, n_estimators=400 ...................................
# [CV] ....... max_depth=5, n_estimators=400, score=0.815, total=   0.9s
# [CV] max_depth=5, n_estimators=400 ...................................
# [CV] ....... max_depth=5, n_estimators=400, score=0.800, total=   0.9s
# [CV] max_depth=5, n_estimators=400 ...................................
# [CV] ....... max_depth=5, n_estimators=400, score=0.852, total=   0.9s
# [CV] max_depth=5, n_estimators=500 ...................................
# [CV] ....... max_depth=5, n_estimators=500, score=0.844, total=   1.1s
# [CV] max_depth=5, n_estimators=500 ...................................
# [CV] ....... max_depth=5, n_estimators=500, score=0.852, total=   1.1s
# [CV] max_depth=5, n_estimators=500 ...................................
# [CV] ....... max_depth=5, n_estimators=500, score=0.822, total=   1.1s
# [CV] max_depth=5, n_estimators=500 ...................................
# [CV] ....... max_depth=5, n_estimators=500, score=0.800, total=   1.3s
# [CV] max_depth=5, n_estimators=500 ...................................
# [CV] ....... max_depth=5, n_estimators=500, score=0.844, total=   1.1s
# [CV] max_depth=5, n_estimators=750 ...................................
# [CV] ....... max_depth=5, n_estimators=750, score=0.844, total=   1.6s
# [CV] max_depth=5, n_estimators=750 ...................................
# [CV] ....... max_depth=5, n_estimators=750, score=0.852, total=   1.6s
# [CV] max_depth=5, n_estimators=750 ...................................
# [CV] ....... max_depth=5, n_estimators=750, score=0.830, total=   1.6s
# [CV] max_depth=5, n_estimators=750 ...................................
# [CV] ....... max_depth=5, n_estimators=750, score=0.800, total=   1.6s
# [CV] max_depth=5, n_estimators=750 ...................................
# [CV] ....... max_depth=5, n_estimators=750, score=0.852, total=   1.6s
# [CV] max_depth=5, n_estimators=1000 ..................................
# [CV] ...... max_depth=5, n_estimators=1000, score=0.852, total=   2.3s
# [CV] max_depth=5, n_estimators=1000 ..................................
# [CV] ...... max_depth=5, n_estimators=1000, score=0.852, total=   2.1s
# [CV] max_depth=5, n_estimators=1000 ..................................
# [CV] ...... max_depth=5, n_estimators=1000, score=0.815, total=   2.1s
# [CV] max_depth=5, n_estimators=1000 ..................................
# [CV] ...... max_depth=5, n_estimators=1000, score=0.800, total=   2.1s
# [CV] max_depth=5, n_estimators=1000 ..................................
# [CV] ...... max_depth=5, n_estimators=1000, score=0.844, total=   2.1s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ........ max_depth=6, n_estimators=10, score=0.830, total=   0.0s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ........ max_depth=6, n_estimators=10, score=0.830, total=   0.0s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ........ max_depth=6, n_estimators=10, score=0.822, total=   0.0s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ........ max_depth=6, n_estimators=10, score=0.793, total=   0.0s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ........ max_depth=6, n_estimators=10, score=0.844, total=   0.0s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] ....... max_depth=6, n_estimators=100, score=0.837, total=   0.2s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] ....... max_depth=6, n_estimators=100, score=0.859, total=   0.2s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] ....... max_depth=6, n_estimators=100, score=0.815, total=   0.2s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] ....... max_depth=6, n_estimators=100, score=0.800, total=   0.2s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] ....... max_depth=6, n_estimators=100, score=0.859, total=   0.2s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] ....... max_depth=6, n_estimators=200, score=0.837, total=   0.4s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] ....... max_depth=6, n_estimators=200, score=0.859, total=   0.4s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] ....... max_depth=6, n_estimators=200, score=0.800, total=   0.4s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] ....... max_depth=6, n_estimators=200, score=0.793, total=   0.4s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] ....... max_depth=6, n_estimators=200, score=0.852, total=   0.4s
# [CV] max_depth=6, n_estimators=300 ...................................
# [CV] ....... max_depth=6, n_estimators=300, score=0.852, total=   0.7s
# [CV] max_depth=6, n_estimators=300 ...................................
# [CV] ....... max_depth=6, n_estimators=300, score=0.852, total=   0.6s
# [CV] max_depth=6, n_estimators=300 ...................................
# [CV] ....... max_depth=6, n_estimators=300, score=0.800, total=   0.6s
# [CV] max_depth=6, n_estimators=300 ...................................
# [CV] ....... max_depth=6, n_estimators=300, score=0.800, total=   0.6s
# [CV] max_depth=6, n_estimators=300 ...................................
# [CV] ....... max_depth=6, n_estimators=300, score=0.852, total=   0.6s
# [CV] max_depth=6, n_estimators=400 ...................................
# [CV] ....... max_depth=6, n_estimators=400, score=0.844, total=   0.9s
# [CV] max_depth=6, n_estimators=400 ...................................
# [CV] ....... max_depth=6, n_estimators=400, score=0.859, total=   0.9s
# [CV] max_depth=6, n_estimators=400 ...................................
# [CV] ....... max_depth=6, n_estimators=400, score=0.800, total=   0.9s
# [CV] max_depth=6, n_estimators=400 ...................................
# [CV] ....... max_depth=6, n_estimators=400, score=0.800, total=   1.0s
# [CV] max_depth=6, n_estimators=400 ...................................
# [CV] ....... max_depth=6, n_estimators=400, score=0.852, total=   0.9s
# [CV] max_depth=6, n_estimators=500 ...................................
# [CV] ....... max_depth=6, n_estimators=500, score=0.844, total=   1.1s
# [CV] max_depth=6, n_estimators=500 ...................................
# [CV] ....... max_depth=6, n_estimators=500, score=0.859, total=   1.1s
# [CV] max_depth=6, n_estimators=500 ...................................
# [CV] ....... max_depth=6, n_estimators=500, score=0.800, total=   1.3s
# [CV] max_depth=6, n_estimators=500 ...................................
# [CV] ....... max_depth=6, n_estimators=500, score=0.800, total=   1.1s
# [CV] max_depth=6, n_estimators=500 ...................................
# [CV] ....... max_depth=6, n_estimators=500, score=0.852, total=   1.1s
# [CV] max_depth=6, n_estimators=750 ...................................
# [CV] ....... max_depth=6, n_estimators=750, score=0.844, total=   1.6s
# [CV] max_depth=6, n_estimators=750 ...................................
# [CV] ....... max_depth=6, n_estimators=750, score=0.859, total=   1.9s
# [CV] max_depth=6, n_estimators=750 ...................................
# [CV] ....... max_depth=6, n_estimators=750, score=0.800, total=   1.8s
# [CV] max_depth=6, n_estimators=750 ...................................
# [CV] ....... max_depth=6, n_estimators=750, score=0.800, total=   1.6s
# [CV] max_depth=6, n_estimators=750 ...................................
# [CV] ....... max_depth=6, n_estimators=750, score=0.852, total=   1.6s
# [CV] max_depth=6, n_estimators=1000 ..................................
# [CV] ...... max_depth=6, n_estimators=1000, score=0.844, total=   2.2s
# [CV] max_depth=6, n_estimators=1000 ..................................
# [CV] ...... max_depth=6, n_estimators=1000, score=0.859, total=   2.2s
# [CV] max_depth=6, n_estimators=1000 ..................................
# [CV] ...... max_depth=6, n_estimators=1000, score=0.800, total=   2.2s
# [CV] max_depth=6, n_estimators=1000 ..................................
# [CV] ...... max_depth=6, n_estimators=1000, score=0.800, total=   2.3s
# [CV] max_depth=6, n_estimators=1000 ..................................
# [CV] ...... max_depth=6, n_estimators=1000, score=0.852, total=   2.1s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed:  3.8min finished
# {'max_depth': 3, 'n_estimators': 500}
# RandomForestClassifier(max_depth=3, n_estimators=500)
# [[67  5  7]
#  [ 5 59  6]
#  [ 1  7 68]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.85      0.88        79
#          1.0       0.83      0.84      0.84        70
#          2.0       0.84      0.89      0.87        76
#
#     accuracy                           0.86       225
#    macro avg       0.86      0.86      0.86       225
# weighted avg       0.86      0.86      0.86       225
