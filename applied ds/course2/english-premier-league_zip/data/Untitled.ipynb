# %%
# %matplotlib inline
import pandas as pd 
import seaborn as sns;sns.set()
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import rcParams

# %%
af=pd.read_csv("season-1516_csv.csv")
bf=pd.read_csv("season-1617_csv.csv")
cf=pd.read_csv("season-1718_csv.csv")
df=pd.read_csv("season-1819_csv.csv")
ef=pd.read_csv("season-1415_csv.csv")
ff=pd.read_csv("season-1314_csv.csv")

# %%
lei=af[(af["HomeTeam"]=="Leicester") | (af["AwayTeam"]=="Leicester")].reset_index(drop=True)
che=bf[(bf["HomeTeam"]=="Chelsea") | (bf["AwayTeam"]=="Chelsea")].reset_index(drop=True)
manc2=cf[(cf["HomeTeam"]=="Man City") | (cf["AwayTeam"]=="Man City")].reset_index(drop=True)
manc3=df[(df["HomeTeam"]=="Man City") | (df["AwayTeam"]=="Man City")].reset_index(drop=True)
che2=ef[(ef["HomeTeam"]=="Chelsea") | (ef["AwayTeam"]=="Chelsea")].reset_index(drop=True)
manc=ff[(ff["HomeTeam"]=="Man City") | (ff["AwayTeam"]=="Man City")].reset_index(drop=True)
liv=df[(df["HomeTeam"]=="Liverpool") | (df["AwayTeam"]=="Liverpool")].reset_index(drop=True)

t=[manc,che,lei,che2,manc2,manc3,liv]
y=["Man City","Chelsea","Leicester","Chelsea","Man City","Man City","Liverpool"]

# %%
j=0
for team in t:
    team["game week"]=pd.Series(range(1,39))
    team["result"]=pd.Series([None]*38)
    team["FTG"]=pd.Series([None]*38)
    team["HTG"]=pd.Series([None]*38)
    team["FCG"]=pd.Series([None]*38)
    team["HCG"]=pd.Series([None]*38)
    ftg=[]
    htg=[]
    fcg=[]
    hcg=[]
    s=[]
    for i in team.index.values.tolist():
        temp=team.loc[i]
        if temp["HomeTeam"]==y[j]:
            ftg.append(temp.FTHG)
            htg.append(temp.HTHG)
            fcg.append(temp.FTAG)
            hcg.append(temp.HTAG)
            if temp.FTR=="H":
                s.append(3)
            elif temp.FTR=="D":
                s.append(1)
            else:
                s.append(0)
        elif temp["AwayTeam"]==y[j]:
            ftg.append(temp.FTAG)
            htg.append(temp.HTAG)
            fcg.append(temp.FTHG)
            hcg.append(temp.HTHG)
            if temp.FTR=="A":
                s.append(3)
            elif temp.FTR=="D":
                s.append(1)
            else:
                s.append(0)
    team.result=pd.Series(s).cumsum(0)
    team.FTG=pd.Series(ftg).cumsum(0)
    team.HTG=pd.Series(htg).cumsum(0)
    team.FCG=pd.Series(fcg).cumsum(0)
    team.HCG=pd.Series(hcg).cumsum(0)
    j+=1
    team.drop(["Div"],inplace=True,axis=1)

# %%
plt.style.use("seaborn-colorblind")
plt.figure()
for i in t:
i.plot(x="game week",y="FTG",ax=plt.gca())

plt.legend(["Leicester","Chelsea","Man City","Man City","Man City","Chelsea","Liverpool"])
plt.show()

# %%
plt.figure()
for i in t:
    i.plot(x="game week",y="FCG",ax=plt.gca())

plt.legend(["Leicester","Chelsea","Man City","Man City","Man City","Chelsea","Liverpool"])

# %%
goals=[]
points=[]
teams=["Man City 13/14","Chelsea 14/15","Leicester 15/16","Chelsea 16/17","Man City 17/18","Man City 18/19","Liverpool 18/19"]
for i in t:
    goals.append(i.FTG.max())
    points.append(i.result.max())

# %%
sns.barplot(x=teams,y=points,palette="Blues")
sns.lineplot(x=teams,y=goals,markers=True,err_style="band")
plt.gca().tick_params(axis="both",labelsize=7)
plt.xticks(rotation=45)
plt.tight_layout()

# %%
plt.figure()
sns.barplot()
plt.style.use("seaborn-colorblind")
a=lf[lf["HomeTeam"]=="Leicester"]["FTR"].value_counts()
sns.barplot(a.index.tolist(),a.values.tolist(),palette="Blues")

# %%
mf=pd.concat([lf[lf["HomeTeam"]=="Leicester"],cf[cf["HomeTeam"]=="Man City"]],axis=0)
vf=pd.concat([lf[lf["AwayTeam"]=="Leicester"],cf[cf["AwayTeam"]=="Man City"]],axis=0)

# %%
mf.shape

# %%
df = mf.groupby(['FTR','HomeTeam']).size().unstack(fill_value=0)
zf = vf.groupby(['FTR','AwayTeam']).size().unstack(fill_value=0)

# %%
def

# %%
plt.figure()
plt.subplot(121)
df.plot.bar(ax=plt.gca())
plt.xticks(range(3),["Loss","Draw","Win"]);
plt.yticks(range(20));
plt.subplot(122)
zf.plot.bar(ax=plt.gca())
plt.xticks(range(3),["Win","Draw","Loss"]);
plt.yticks(range(20));

# %%
lf.shape

# %%
lf["result"]=pd.Series([None]*38)

# %%
lf["result"]=pd.Series([None]*38)
s=[]
for i in lf.index.values.tolist():
    temp=lf.loc[i]
    if temp["HomeTeam"]=="Leicester":
        if temp.FTR=="H":
            s.append(3)
        elif temp.FTR=="D":
            s.append(1)
        else:
            s.append(0)
    elif temp["AwayTeam"]=="Leicester":
        if temp.FTR=="A":
            s.append(3)
        elif temp.FTR=="D":
            s.append(1)
        else:
            s.append(0)
lf.result=pd.Series(s).cumsum(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6490a85a86cd> in <module>
# ----> 1 lf["result"]=pd.Series([None]*38)
#       2 s=[]
#       3 for i in lf.index.values.tolist():
#       4     temp=lf.loc[i]
#       5     if temp["HomeTeam"]=="Leicester":
#
# NameError: name 'lf' is not defined

# %%
cf["result"]=pd.Series([None]*38)
s=[]
for i in cf.index.values.tolist():
    temp=cf.loc[i]
    if temp["HomeTeam"]=="Man City":
        if temp.FTR=="H":
            s.append(3)
        elif temp.FTR=="D":
            s.append(1)
        else:
            s.append(0)
    elif temp["AwayTeam"]=="Man City":
        if temp.FTR=="A":
            s.append(3)
        elif temp.FTR=="D":
            s.append(1)
        else:
            s.append(0)
            
cf.result=pd.Series(s).cumsum(0)

# %%
cf.head()
# Out:
#   Div        Date  HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  12/08/2018   Arsenal      Man City     0     2   A     0     1   A
# 1  E0  19/08/2018  Man City  Huddersfield     6     1   H     3     1   H
# 2  E0  25/08/2018    Wolves      Man City     1     1   D     0     0   D
# 3  E0  01/09/2018  Man City     Newcastle     2     1   H     1     1   D
# 4  E0  15/09/2018  Man City        Fulham     3     0   H     2     0   H
#
#    ... BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA   PSCH   PSCD   PSCA  \
# 0  ...   20   0.75     1.78     1.74     2.21     2.15   4.43   4.13   1.81
# 1  ...   20  -3.00     2.31     2.24     1.72     1.68   1.08  13.93  36.05
# 2  ...   21   2.00     1.67     1.61     2.51     2.37  12.01   5.82   1.30
# 3  ...   19  -2.50     2.02     1.99     1.93     1.89   1.12  10.43  29.28
# 4  ...   23  -2.50     2.00     1.95     1.96     1.92   1.10  12.75  25.00
#
#    result
# 0       3
# 1       6
# 2       7
# 3      10
# 4      13
#
# [5 rows x 63 columns]

# %%
len(s)
# Out:
# 38

# %%
lf["game week"]=pd.Series(range(1,39))

# %%
cf["game week"]=pd.Series(range(1,39))

# %%
lf.rename(columns={"result":"points"})
plt.figure()
sns.lineplot(x="game week",y="points",data=lf)
plt.xticks(range(1,39));
plt.gca().tick_params(axis="both",labelsize=7);
cf.rename(columns={"result":"points"},inplace=True)
sns.lineplot(x="game week",y="points",data=cf)
plt.xticks(range(1,39));
plt.gca().tick_params(axis="both",labelsize=7);
plt.axvline(19,alpha=0.5);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lf.head()
# Out:
#        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  08/08/15    Leicester   Sunderland     4     2   H     3     0   H
# 1  15/08/15     West Ham    Leicester     1     2   A     0     2   A
# 2  22/08/15    Leicester    Tottenham     1     1   D     0     0   D
# 3  29/08/15  Bournemouth    Leicester     1     1   D     1     0   H
# 4  13/09/15    Leicester  Aston Villa     3     2   H     0     1   A
#
#        Referee  ...  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  \
# 0      L Mason  ...  -0.50     2.00     1.95     1.96     1.90  1.79  3.74
# 1     A Taylor  ...  -0.25     1.98     1.92     1.99     1.93  2.38  3.54
# 2   M Atkinson  ...   0.00     1.96     1.90     2.01     1.93  2.61  3.50
# 3  N Swarbrick  ...  -0.25     1.88     1.84     2.08     2.02  2.06  3.65
# 4       M Dean  ...  -0.50     1.89     1.85     2.08     2.01  1.88  3.78
#
#    PSCA  result  game week
# 0  5.10       3          1
# 1  3.15       6          2
# 2  2.85       7          3
# 3  3.82       8          4
# 4  4.47      11          5
#
# [5 rows x 66 columns]

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
